# %%
import pymc3 as pm
import arviz as az
import theano.tensor as tt

import numpy as np
import matplotlib.pyplot as plt
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
tau_m = 0.01
J = -1 * tau_m

def approx_q(nu_bar,alpha_0,tau_I):
    
    #tau_I = paras['tau_I']
    #alpha_0 = paras['alpha_0']
    #nu_bar = paras['nu_bar']
    
    nu_max = 1. / (2. * np.pi * np.sqrt( tau_I * tau_m ) )
    tau_q = 2. * (tau_I + tau_m)
    q_0 = alpha_0**2 / J**2.
        
    eps = tau_q * ( nu_bar**2 + q_0 ) / ( nu_bar + 2. * tau_q * (nu_bar**2 + q_0) )
    
    q = 1. / np.sqrt( 1. + 2 * tau_q * ( nu_bar + q_0 / nu_bar ) ) * \
        ( 1. + tau_q * ( nu_bar + q_0 / nu_bar ))**( 1. - eps ) * \
        nu_max**( 2. * eps ) * nu_bar**( 2. - 2. * eps )
    
    return q

def p_nu(NU,gamma,delta,nu_max):

    return gamma / ( nu_max * np.sqrt( -np.pi * np.log( NU / nu_max ) ) ) * \
        np.exp( - delta**2/2.) * ( NU / nu_max )**(gamma**2 - 1) * \
        np.cosh( gamma * delta * np.sqrt( -2 * np.log( NU / nu_max) ) )

def logP_nu(NU,gamma,delta,nu_max):
    
    return - np.log( nu_max / gamma * np.sqrt( -np.pi * np.log( NU / nu_max ) ) ) - delta**2 / 2 + \
        ( gamma**2 - 1 ) * np.log( NU / nu_max ) + \
        np.log( np.cosh( gamma * delta * np.sqrt( -2 * np.log( NU / nu_max ) ) ) )

def logp_raw(NU,nu_bar,alpha_0,tau_I):
    
    # introduce checks for consistency, etc

    nu_max = 1. / (2. * np.pi * np.sqrt( tau_I * tau_m ) )

    q = approx_q(nu_bar,alpha_0,tau_I)

    sigma_I = np.sqrt(J**2 * nu_bar / ( 2 * tau_I ))
    sigma_V = np.sqrt(sigma_I**2 * tau_I / (tau_I + tau_m))
    alpha = np.sqrt(J**2 * q + alpha_0**2)

    selfcon_nu = nu_bar/nu_max * np.sqrt( alpha**2/sigma_V**2 + 1)
    selfcon_q = q/nu_max**2 * np.sqrt( 2*alpha**2/sigma_V**2 + 1)

    #if ((selfcon_nu < 1) and (selfcon_q < 1)):

    gamma = sigma_V / alpha

    I_0 = np.sqrt( -( alpha**2 + sigma_V**2 ) * np.log( ( nu_bar / nu_max )**2 * ( alpha**2/sigma_V**2 + 1 ) ) )
    delta = I_0 / alpha
    
    p_ = p_nu(NU,gamma,delta,nu_max)
    logP_ = logP_nu(NU,gamma,delta,nu_max)
    
    return p_, logP_

# %%
## create data for inference, or read from model
# %cd ..
from create_measures import *
res = create_measures(L=1,S=[1,2],rerun=True)
print(res)
# Out:
# /home/wollex/Data/Documents/Science/WolfGroup/DarkMatter/Programme
# {'rates': masked_array(
#   data=[[5.38224243e-03, 9.24571477e-01, 1.28933335e+00, 1.74894160e-02],
#         [5.62277173e-01, 4.61925564e-01, 3.25398331e-01, 7.26459231e-01],
#         [1.55034029e-03, 1.63974308e+00, 7.12273504e-01, 1.92580477e+00],
#         [3.82843490e-01, 2.08365856e-01, 2.02826657e+00, 6.12892010e-02],
#         [1.96805364e-01, 1.39317766e+00, 1.88987021e-02, 1.20879603e+00],
#         [4.54886448e-02, 2.99919988e-01, 1.11439394e-01, 9.66398026e-03],
#         [1.22523270e+00, 2.46486035e+00, 2.60855452e+00, 4.81937407e+00],
#         [5.36862806e+00, 3.78147591e-01, 1.63380704e-02, 3.52761988e-01],
#         [4.38688020e-02, 2.38207343e+00, 1.30426538e+00, 8.40850648e-02],
#         [1.01907064e+01, 1.16768871e+00, 1.76943143e-02, 7.63260559e-01],
#         [2.98733988e+00, 3.86023012e+00, 8.85700927e-02, 4.47927163e-01],
#         [1.03627666e-02, 3.40058369e-01, 5.14963354e-01, 5.55141152e-02],
#         [1.18467882e-01, 9.36429163e-01, 6.50684256e-01, 7.68542653e-03],
#         [6.39764954e-01, 7.38844819e-02, 6.80265682e-02, 1.31010496e+00],
#         [1.56136027e-01, 2.65085230e-02, 1.24393277e+00, 3.98035648e-03],
#         [9.68668938e-02, 3.31980655e-02, 9.59267015e-02, 5.02404803e-01],
#         [1.11406199e-01, 8.92959552e+00, 5.59278064e-03, 1.15451549e-01],
#         [2.92527160e-03, 1.69384378e-01, 5.39822474e-02, 3.48905840e-01],
#         [1.77513246e+00, 1.72809089e+00, 2.01179397e+00, 2.25976208e-01],
#         [3.12182356e-01, 2.34451724e-01, 1.02078761e+00, 3.44479435e-02],
#         [5.31924294e-01, 1.50941891e+00, 2.35539666e-01, 5.59539658e-01],
#         [7.33735406e-02, 1.19031305e+00, 7.15336951e-01, 1.81805947e-01],
#         [1.18401901e+00, 1.53111723e-01, 5.37150356e-03, 8.59429415e-02],
#         [1.74338215e+00, 7.16564710e-01, 1.96086531e+00, 1.00536551e+00],
#         [2.84241257e-02, 1.27544834e-01, 6.59468920e-02, 6.77620392e+00],
#         [3.02375832e-01, 2.83016477e-01, 8.61224859e-02, 1.02606250e-02],
#         [2.13167877e-01, 8.66837736e-01, 2.86925123e-02, 2.84512879e-02],
#         [5.90243181e-01, 1.37720022e-01, 9.51771994e-01, 2.51696399e-02],
#         [7.38743915e-02, 2.18731139e-02, 2.69713198e-01, 7.80269610e+00],
#         [9.52899546e-02, 3.58890060e+00, 2.15142488e-01, 5.96368869e+00],
#         [2.54448599e+00, 2.32540598e-01, 1.75383339e-02, 8.84369511e-01],
#         [1.01650580e+00, 1.80699858e-03, 1.74118019e-02, 1.27667573e+00],
#         [3.59990693e-02, 1.20130872e+00, 1.53946172e-02, 9.72904283e+00],
#         [7.45375391e-01, 1.94321095e+00, 4.12858217e+00, 3.06913702e-01],
#         [2.25984109e-01, 2.31574169e-02, 2.39899795e+00, 3.08532319e+00],
#         [6.97974778e-04, 1.28957284e-02, 2.23317837e-02, 6.53730701e-02],
#         [3.20974713e-01, 2.87891047e-01, 1.16584666e-01, 2.47431066e-01],
#         [2.18321839e+00, 1.59589927e-01, 4.24336789e-01, 1.01947973e+00],
#         [2.63451246e+00, 2.67570515e+00, 1.46620390e-01, 1.87975851e-01],
#         [2.48164170e-02, 1.06294263e-02, 1.02470143e+00, 7.03435372e-03],
#         [1.12330992e+00, 4.13587001e-03, 5.66527224e+00, 6.83629232e-03],
#         [4.73389506e+00, 3.54647304e-01, 1.99379769e+00, 3.84153162e-01],
#         [7.59472876e-01, 7.51028769e-02, 5.14232166e-02, 2.01747298e+00],
#         [5.02576154e-02, 2.20370206e-02, 8.20359377e-02, 1.08011134e-01],
#         [2.30062153e-01, 2.32744683e+00, 1.92115772e-01, 2.23116963e-01],
#         [3.16504094e+00, 2.72962366e-02, 2.16827045e-02, 1.82202707e-02],
#         [1.69875794e-02, 2.75079783e+00, 2.49408293e-02, 1.73700303e+00],
#         [2.36158172e+00, 2.14127198e-01, 3.25091406e-01, 2.58258209e-01],
#         [1.37199576e+00, 2.22492708e-02, 2.14998291e-01, 1.08351854e-01],
#         [4.91379195e-02, 1.50370958e-02, 1.57141338e-02, 1.33270253e+00],
#         [1.04445621e-01, 2.14652995e-01, 1.37734939e+00, 1.02906775e-03],
#         [5.45090659e+00, 1.00417469e-01, 7.82385748e-01, 8.54955737e-04],
#         [1.91027870e-01, 1.39775075e+00, 3.49685125e+00, 2.27892234e-02],
#         [1.98271787e-01, 4.62128961e-02, 1.30279706e+00, 4.63610811e-01],
#         [4.71144181e+00, 4.21913214e+00, 4.85201601e-02, 1.40307410e+00],
#         [1.15401204e-01, 4.18951990e-03, 2.03621760e+00, 9.89260557e-03],
#         [2.15652407e+00, 2.13196877e-02, 3.62123248e+00, 3.23771974e-01],
#         [5.29787929e-02, 4.43744406e-03, 1.92669179e-01, 2.42182911e-01],
#         [1.06021074e+00, 1.36246673e-02, 1.54349926e+00, 1.06558791e+00],
#         [6.00156671e+00, 1.70775444e-02, 4.92743225e+00, 1.58867087e-01],
#         [1.06261398e-01, 1.25681602e+00, 2.72882295e+00, 2.66298892e+00],
#         [1.11518935e-01, 3.93365047e+00, 6.18051419e-01, 1.05975202e+00],
#         [1.91459224e+00, 5.98846285e-02, 3.96212278e-01, 6.63494477e-02],
#         [1.23221109e+00, 2.97924499e-02, 1.53952665e+00, 3.87199070e+00],
#         [3.29447211e+00, 1.03693614e+00, 2.58774044e+00, 6.02934790e-01],
#         [5.90478043e-02, 9.98495876e-02, 4.13843059e-02, 5.36760992e+00],
#         [2.29641710e-01, 1.16549012e+00, 3.67804008e-01, 6.77647473e-01],
#         [1.02717418e-01, 1.76721532e-01, 2.26101303e+00, 2.71159940e-01],
#         [4.13821429e+00, 1.79317405e-02, 7.22059510e-01, 1.92918567e-02],
#         [6.68900302e-02, 3.88245208e+00, 4.12241403e-01, 4.61952982e-02],
#         [5.19635293e-01, 2.03283784e+00, 2.94903000e+00, 8.74444492e-02],
#         [3.71354443e-02, 1.30907387e+00, 1.10477536e+01, 7.30165899e-02],
#         [4.33940528e-01, 3.57013557e+00, 1.08977699e-01, 1.04397155e+00],
#         [1.00970058e-01, 5.03220398e-01, 5.59755717e-03, 7.77822143e-02],
#         [4.48518016e-02, 2.45770528e-02, 7.10175122e-01, 4.19576201e-02],
#         [2.51889573e-02, 2.12962929e+00, 2.20956768e-02, 3.10922536e-02],
#         [2.55936111e+00, 1.54571290e-01, 7.15025115e+00, 1.88829458e-02],
#         [2.18228842e-02, 6.87885164e+00, 1.05563739e+00, 6.37373302e-02],
#         [7.35420460e-02, 2.68375141e-01, 8.97544739e-03, 1.08927474e+00],
#         [4.54016944e-01, 3.43710838e-01, 7.21384162e-01, 5.32688773e-01],
#         [5.64450138e-02, 1.64948522e+00, 1.59795686e+00, 4.15311231e-01],
#         [1.08036517e-01, 9.80491591e-03, 3.51467057e-01, 3.40205738e-01],
#         [5.78104514e-02, 4.60124183e-01, 2.52085813e+00, 4.90945415e-03],
#         [2.54859582e-01, 1.79368383e+00, 1.50851104e+00, 4.17641314e-04],
#         [4.03949657e-01, 7.88171628e-01, 6.56145250e-01, 3.40424114e-01],
#         [4.75306461e-02, 1.01133437e+00, 2.19710326e+00, 6.06104158e+00],
#         [7.58414215e-01, 7.48789781e-01, 2.83239150e+00, 2.22014186e+00],
#         [8.46431626e-01, 1.44572856e-02, 6.33458918e+00, 6.90708823e+00],
#         [1.76757122e+00, 6.65237265e-02, 1.16125526e-01, 1.02680374e+01],
#         [3.62567911e-02, 6.11363296e-02, 8.35975156e-01, 6.25170046e-02],
#         [5.93409802e+00, 1.42486064e+00, 5.07020161e+00, 2.03337867e-02],
#         [1.01489741e-01, 5.00024135e-02, 8.80245817e-03, 8.51582380e+00],
#         [1.12960023e-01, 9.43369372e-02, 1.43084930e+00, 2.41494565e+00],
#         [1.22457665e+00, 6.77664815e-01, 1.36778021e-02, 1.23988098e+00],
#         [7.39225311e-02, 7.17873151e-02, 4.40039273e-02, 2.16049022e-01],
#         [3.94812619e-01, 6.03882438e-01, 3.46998697e-02, 6.80876998e-02],
#         [6.63811937e-02, 5.41860366e-01, 1.00213838e-01, 3.37218912e-02],
#         [4.83139945e-02, 1.68627992e-01, 1.34974954e+00, 6.84910118e-01],
#         [3.80424702e-01, 3.68264154e+00, 1.28477522e-01, 2.12363710e-01],
#         [1.67261529e+00, 1.55149841e-01, 8.42879124e+00, 1.45401528e-01]],
#   mask=False,
#   fill_value=1e+20), 'rates_T': masked_array(
#   data=[[[5.00000000e-03],
#          [9.01666667e-01],
#          [1.22500000e+00],
#          [1.50000000e-02]],
#
#         [[5.41666667e-01],
#          [4.25000000e-01],
#          [3.40000000e-01],
#          [7.25000000e-01]],
#
#         [[3.33333333e-03],
#          [1.61500000e+00],
#          [6.76666667e-01],
#          [1.95333333e+00]],
#
#         [[4.30000000e-01],
#          [2.13333333e-01],
#          [1.98500000e+00],
#          [6.50000000e-02]],
#
#         [[1.96666667e-01],
#          [1.32333333e+00],
#          [1.50000000e-02],
#          [1.17500000e+00]],
#
#         [[4.83333333e-02],
#          [2.76666667e-01],
#          [1.40000000e-01],
#          [1.00000000e-02]],
#
#         [[1.19833333e+00],
#          [2.41666667e+00],
#          [2.57666667e+00],
#          [4.66666667e+00]],
#
#         [[5.42833333e+00],
#          [3.58333333e-01],
#          [2.00000000e-02],
#          [3.31666667e-01]],
#
#         [[4.50000000e-02],
#          [2.51166667e+00],
#          [1.29333333e+00],
#          [6.50000000e-02]],
#
#         [[1.01783333e+01],
#          [1.17500000e+00],
#          [2.00000000e-02],
#          [7.76666667e-01]],
#
#         [[2.95833333e+00],
#          [3.82000000e+00],
#          [9.16666667e-02],
#          [4.65000000e-01]],
#
#         [[1.00000000e-02],
#          [3.48333333e-01],
#          [5.30000000e-01],
#          [4.16666667e-02]],
#
#         [[1.20000000e-01],
#          [9.38333333e-01],
#          [6.93333333e-01],
#          [3.33333333e-03]],
#
#         [[6.01666667e-01],
#          [6.50000000e-02],
#          [6.50000000e-02],
#          [1.37166667e+00]],
#
#         [[1.28333333e-01],
#          [2.83333333e-02],
#          [1.18666667e+00],
#          [5.00000000e-03]],
#
#         [[9.16666667e-02],
#          [4.66666667e-02],
#          [9.66666667e-02],
#          [5.05000000e-01]],
#
#         [[1.11666667e-01],
#          [9.15666667e+00],
#          [3.33333333e-03],
#          [1.08333333e-01]],
#
#         [[1.66666667e-03],
#          [1.95000000e-01],
#          [4.66666667e-02],
#          [3.46666667e-01]],
#
#         [[1.89000000e+00],
#          [1.69333333e+00],
#          [2.01500000e+00],
#          [2.86666667e-01]],
#
#         [[2.93333333e-01],
#          [2.35000000e-01],
#          [1.03833333e+00],
#          [4.00000000e-02]],
#
#         [[5.10000000e-01],
#          [1.51333333e+00],
#          [2.48333333e-01],
#          [5.43333333e-01]],
#
#         [[9.16666667e-02],
#          [1.22833333e+00],
#          [7.01666667e-01],
#          [1.66666667e-01]],
#
#         [[1.15833333e+00],
#          [1.33333333e-01],
#          [6.66666667e-03],
#          [8.83333333e-02]],
#
#         [[1.74000000e+00],
#          [6.55000000e-01],
#          [1.91833333e+00],
#          [9.76666667e-01]],
#
#         [[3.50000000e-02],
#          [1.11666667e-01],
#          [6.16666667e-02],
#          [6.90166667e+00]],
#
#         [[2.50000000e-01],
#          [2.76666667e-01],
#          [1.16666667e-01],
#          [1.33333333e-02]],
#
#         [[2.25000000e-01],
#          [8.33333333e-01],
#          [2.50000000e-02],
#          [3.00000000e-02]],
#
#         [[5.80000000e-01],
#          [1.48333333e-01],
#          [9.18333333e-01],
#          [1.50000000e-02]],
#
#         [[6.33333333e-02],
#          [2.33333333e-02],
#          [2.73333333e-01],
#          [7.58500000e+00]],
#
#         [[9.33333333e-02],
#          [3.64833333e+00],
#          [2.05000000e-01],
#          [6.05000000e+00]],
#
#         [[2.45666667e+00],
#          [2.06666667e-01],
#          [1.33333333e-02],
#          [8.58333333e-01]],
#
#         [[9.98333333e-01],
#          [6.66666667e-03],
#          [1.50000000e-02],
#          [1.26500000e+00]],
#
#         [[3.66666667e-02],
#          [1.23833333e+00],
#          [1.83333333e-02],
#          [9.77833333e+00]],
#
#         [[7.51666667e-01],
#          [1.84500000e+00],
#          [4.13833333e+00],
#          [3.01666667e-01]],
#
#         [[2.03333333e-01],
#          [2.83333333e-02],
#          [2.48500000e+00],
#          [3.02833333e+00]],
#
#         [[0.00000000e+00],
#          [1.16666667e-02],
#          [1.66666667e-02],
#          [6.33333333e-02]],
#
#         [[3.50000000e-01],
#          [3.25000000e-01],
#          [1.10000000e-01],
#          [2.21666667e-01]],
#
#         [[2.12666667e+00],
#          [1.71666667e-01],
#          [4.61666667e-01],
#          [1.02666667e+00]],
#
#         [[2.68000000e+00],
#          [2.61166667e+00],
#          [1.43333333e-01],
#          [1.88333333e-01]],
#
#         [[3.33333333e-02],
#          [1.83333333e-02],
#          [1.07166667e+00],
#          [8.33333333e-03]],
#
#         [[1.15000000e+00],
#          [3.33333333e-03],
#          [5.65500000e+00],
#          [3.33333333e-03]],
#
#         [[4.75166667e+00],
#          [4.10000000e-01],
#          [1.99666667e+00],
#          [3.95000000e-01]],
#
#         [[7.60000000e-01],
#          [7.00000000e-02],
#          [5.50000000e-02],
#          [2.16166667e+00]],
#
#         [[4.00000000e-02],
#          [3.50000000e-02],
#          [9.66666667e-02],
#          [1.01666667e-01]],
#
#         [[2.35000000e-01],
#          [2.41166667e+00],
#          [1.66666667e-01],
#          [2.18333333e-01]],
#
#         [[3.18833333e+00],
#          [3.83333333e-02],
#          [2.66666667e-02],
#          [1.83333333e-02]],
#
#         [[1.50000000e-02],
#          [2.71000000e+00],
#          [2.50000000e-02],
#          [1.73833333e+00]],
#
#         [[2.42000000e+00],
#          [2.13333333e-01],
#          [3.23333333e-01],
#          [2.55000000e-01]],
#
#         [[1.31333333e+00],
#          [2.33333333e-02],
#          [1.96666667e-01],
#          [9.66666667e-02]],
#
#         [[5.00000000e-02],
#          [1.66666667e-02],
#          [1.33333333e-02],
#          [1.27333333e+00]],
#
#         [[1.15000000e-01],
#          [2.13333333e-01],
#          [1.29833333e+00],
#          [1.66666667e-03]],
#
#         [[5.36666667e+00],
#          [8.00000000e-02],
#          [8.00000000e-01],
#          [0.00000000e+00]],
#
#         [[1.73333333e-01],
#          [1.36166667e+00],
#          [3.49000000e+00],
#          [2.66666667e-02]],
#
#         [[2.00000000e-01],
#          [3.16666667e-02],
#          [1.27500000e+00],
#          [4.13333333e-01]],
#
#         [[4.77666667e+00],
#          [4.11500000e+00],
#          [5.83333333e-02],
#          [1.48500000e+00]],
#
#         [[1.25000000e-01],
#          [0.00000000e+00],
#          [2.05333333e+00],
#          [1.33333333e-02]],
#
#         [[2.20666667e+00],
#          [1.83333333e-02],
#          [3.65000000e+00],
#          [2.80000000e-01]],
#
#         [[6.16666667e-02],
#          [5.00000000e-03],
#          [2.01666667e-01],
#          [2.28333333e-01]],
#
#         [[1.07666667e+00],
#          [2.00000000e-02],
#          [1.60333333e+00],
#          [1.12666667e+00]],
#
#         [[5.97833333e+00],
#          [3.00000000e-02],
#          [4.87666667e+00],
#          [1.41666667e-01]],
#
#         [[9.83333333e-02],
#          [1.27666667e+00],
#          [2.70000000e+00],
#          [2.60666667e+00]],
#
#         [[1.25000000e-01],
#          [3.86833333e+00],
#          [5.90000000e-01],
#          [1.04666667e+00]],
#
#         [[1.94666667e+00],
#          [4.16666667e-02],
#          [3.48333333e-01],
#          [7.33333333e-02]],
#
#         [[1.23666667e+00],
#          [3.00000000e-02],
#          [1.46666667e+00],
#          [3.89666667e+00]],
#
#         [[3.30333333e+00],
#          [1.04000000e+00],
#          [2.63500000e+00],
#          [5.25000000e-01]],
#
#         [[7.00000000e-02],
#          [9.16666667e-02],
#          [4.00000000e-02],
#          [5.38166667e+00]],
#
#         [[2.66666667e-01],
#          [1.21333333e+00],
#          [3.30000000e-01],
#          [6.93333333e-01]],
#
#         [[1.15000000e-01],
#          [1.76666667e-01],
#          [2.26500000e+00],
#          [2.58333333e-01]],
#
#         [[4.13166667e+00],
#          [1.66666667e-02],
#          [7.56666667e-01],
#          [1.50000000e-02]],
#
#         [[7.66666667e-02],
#          [4.13333333e+00],
#          [4.16666667e-01],
#          [6.33333333e-02]],
#
#         [[5.70000000e-01],
#          [2.01000000e+00],
#          [3.05500000e+00],
#          [1.06666667e-01]],
#
#         [[2.16666667e-02],
#          [1.34333333e+00],
#          [1.09833333e+01],
#          [8.00000000e-02]],
#
#         [[4.10000000e-01],
#          [3.65000000e+00],
#          [1.41666667e-01],
#          [1.04000000e+00]],
#
#         [[1.06666667e-01],
#          [4.58333333e-01],
#          [1.66666667e-03],
#          [7.16666667e-02]],
#
#         [[6.00000000e-02],
#          [2.66666667e-02],
#          [7.15000000e-01],
#          [4.33333333e-02]],
#
#         [[3.16666667e-02],
#          [2.13333333e+00],
#          [1.83333333e-02],
#          [4.33333333e-02]],
#
#         [[2.47000000e+00],
#          [1.35000000e-01],
#          [7.16833333e+00],
#          [2.33333333e-02]],
#
#         [[1.83333333e-02],
#          [6.88166667e+00],
#          [1.13166667e+00],
#          [6.16666667e-02]],
#
#         [[8.33333333e-02],
#          [2.58333333e-01],
#          [6.66666667e-03],
#          [1.10666667e+00]],
#
#         [[4.28333333e-01],
#          [3.40000000e-01],
#          [7.75000000e-01],
#          [5.25000000e-01]],
#
#         [[5.83333333e-02],
#          [1.68500000e+00],
#          [1.56166667e+00],
#          [4.08333333e-01]],
#
#         [[1.31666667e-01],
#          [6.66666667e-03],
#          [3.83333333e-01],
#          [3.61666667e-01]],
#
#         [[4.16666667e-02],
#          [4.40000000e-01],
#          [2.54500000e+00],
#          [0.00000000e+00]],
#
#         [[2.36666667e-01],
#          [1.69333333e+00],
#          [1.53500000e+00],
#          [0.00000000e+00]],
#
#         [[3.58333333e-01],
#          [8.55000000e-01],
#          [6.16666667e-01],
#          [3.18333333e-01]],
#
#         [[4.33333333e-02],
#          [9.18333333e-01],
#          [2.24333333e+00],
#          [6.21833333e+00]],
#
#         [[7.01666667e-01],
#          [6.63333333e-01],
#          [2.90333333e+00],
#          [2.27000000e+00]],
#
#         [[8.75000000e-01],
#          [1.00000000e-02],
#          [6.45666667e+00],
#          [6.67333333e+00]],
#
#         [[1.75500000e+00],
#          [5.33333333e-02],
#          [1.10000000e-01],
#          [1.02100000e+01]],
#
#         [[3.50000000e-02],
#          [3.83333333e-02],
#          [7.56666667e-01],
#          [6.00000000e-02]],
#
#         [[5.84166667e+00],
#          [1.36166667e+00],
#          [5.04166667e+00],
#          [2.66666667e-02]],
#
#         [[9.16666667e-02],
#          [2.83333333e-02],
#          [1.16666667e-02],
#          [8.41166667e+00]],
#
#         [[1.20000000e-01],
#          [7.83333333e-02],
#          [1.48166667e+00],
#          [2.49000000e+00]],
#
#         [[1.23166667e+00],
#          [6.98333333e-01],
#          [8.33333333e-03],
#          [1.23333333e+00]],
#
#         [[7.00000000e-02],
#          [6.33333333e-02],
#          [4.83333333e-02],
#          [2.58333333e-01]],
#
#         [[4.05000000e-01],
#          [5.50000000e-01],
#          [4.16666667e-02],
#          [5.33333333e-02]],
#
#         [[7.33333333e-02],
#          [5.46666667e-01],
#          [8.50000000e-02],
#          [2.33333333e-02]],
#
#         [[5.33333333e-02],
#          [1.56666667e-01],
#          [1.34666667e+00],
#          [6.43333333e-01]],
#
#         [[4.33333333e-01],
#          [3.62166667e+00],
#          [1.58333333e-01],
#          [1.91666667e-01]],
#
#         [[1.71666667e+00],
#          [1.38333333e-01],
#          [8.44166667e+00],
#          [1.36666667e-01]]],
#   mask=False,
#   fill_value=1e+20)}

# %%
NU = np.squeeze(res['rates_T'])
#NU[NU==0] = 0.001
groups = np.array([len(rates)*[i] for i,rates in enumerate(NU.T)]).flatten()

n = NU.shape[1] # number of distinct tuples of (animals, hemispheres, layers)
obs_nu_bar = np.mean(NU,axis=0)   # should have 

for i in range(n):
    plt.hist(NU[:,i],np.linspace(0,5,51))
    
plt.show()

# %%
nnn = NU.flatten()
np.min(NU)

nu_max = 1. / (2. * np.pi * np.sqrt( 0.005 * tau_m ) )
nu_max
# Out:
# 22.507907903927652

# %%
with pm.Model() as model:
    # replace normals with student-t distributions
    mu_alpha_0 = pm.HalfStudentT('mu_alpha_0',sigma=0.01,nu=1.);
    sigma_alpha_0 = pm.HalfStudentT('sigma_alpha_0',sigma=0.02,nu=1.);
    
    alpha_0 = pm.HalfStudentT('alpha_0',sigma=mu_alpha_0,nu=sigma_alpha_0,shape=n);
    
    
    nu_bar = pm.Normal('nu_bar',obs_nu_bar,0.5,shape=n);
    
    
    mu_tau_I = pm.HalfStudentT('mu_tau_I',sigma=0.01,nu=1.);
    sigma_tau_I = pm.HalfStudentT('sigma_tau_I',sigma=0.01,nu=1.);
    
    tau_I = pm.HalfNormal('tau_I',sigma=sigma_tau_I,shape=n);  #mu=mu_tau_I,
    
    
    def likelihood(NU):
        # introduce checks for consistency, etc
        
        nu_max = 1. / (2. * np.pi * np.sqrt( tau_I * tau_m ) )
        
        q = approx_q(nu_bar,alpha_0,tau_I)
        
        sigma_I = np.sqrt(J**2 * nu_bar / ( 2 * tau_I ))
        sigma_V = np.sqrt(sigma_I**2 * tau_I / (tau_I + tau_m))
        alpha = np.sqrt(J**2 * q + alpha_0**2)
        
        selfcon_nu = nu_bar/nu_max * np.sqrt( alpha**2/sigma_V**2 + 1)
        selfcon_q = q/nu_max**2 * np.sqrt( 2*alpha**2/sigma_V**2 + 1)
        
        #if ((selfcon_nu < 1) and (selfcon_q < 1)):

        gamma = sigma_V / alpha

        I_0 = np.sqrt( -( alpha**2 + sigma_V**2 ) * np.log( ( nu_bar / nu_max )**2 * ( alpha**2/sigma_V**2 + 1 ) ) )
        delta = I_0 / alpha
        
        #tt.printing.Print('nu_bar')(nu_bar)
        #tt.printing.Print('alpha_0')(alpha_0)
        tt.printing.Print('mu_tau_I')(mu_tau_I)
        tt.printing.Print('sigma_tau_I')(sigma_tau_I)
        tt.printing.Print('tau_I')(tau_I)

        logP_ = logP_nu(NU,gamma,delta,nu_max)
        tt.printing.Print('logP_')(logP_)
        logP_ = tt.set_subtensor(logP_[tt.isnan(logP_)],-1000)
        return logP_
        
        
        #logP_sum = np.nansum(logP_)
            #if np.isnan(logP_sum):
            #    logP_sum = -1000
        #    return logP_sum
        #else:
        #    return -1000
       
        # return logp_
    
    logP = pm.DensityDist('logP',likelihood,observed=NU)
                   
    trace = pm.sample(return_inferencedata=True)
# Out:
# mu_tau_I __str__ = 0.010000000000000004
# sigma_tau_I __str__ = 0.010000000000000004
# tau_I __str__ = [0.00797885 0.00797885 0.00797885 0.00797885]
# mu_tau_I __str__ = 0.010000000000000004
# sigma_tau_I __str__ = 0.010000000000000004
# tau_I __str__ = [0.00797885 0.00797885 0.00797885 0.00797885]
# /tmp/ipykernel_27239/1919101471.py:30: RuntimeWarning: divide by zero encountered in log
#   return - np.log( nu_max / gamma * np.sqrt( -np.pi * np.log( NU / nu_max ) ) ) - delta**2 / 2 + \
# /tmp/ipykernel_27239/1919101471.py:31: RuntimeWarning: divide by zero encountered in log
#   ( gamma**2 - 1 ) * np.log( NU / nu_max ) + \
# /tmp/ipykernel_27239/1919101471.py:32: RuntimeWarning: divide by zero encountered in log
#   np.log( np.cosh( gamma * delta * np.sqrt( -2 * np.log( NU / nu_max ) ) ) )
# mu_tau_I __str__ = 0.010000000000000004
# sigma_tau_I __str__ = 0.010000000000000004
# tau_I __str__ = [0.00797885 0.00797885 0.00797885 0.00797885]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [tau_I, sigma_tau_I, mu_tau_I, nu_bar, alpha_0, sigma_alpha_0, mu_alpha_0]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='162' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       4.05% [162/4000 00:00<00:04 Sampling 2 chains, 0 divergences]
#     </div>
# /home/wollex/.local/share/virtualenvs/Programme-856uYgoc/lib/python3.8/site-packages/pymc3/step_methods/hmc/quadpotential.py:220: RuntimeWarning: divide by zero encountered in true_divide
#   np.divide(1, self._stds, out=self._inv_stds)
# /home/wollex/.local/share/virtualenvs/Programme-856uYgoc/lib/python3.8/site-packages/pymc3/step_methods/hmc/quadpotential.py:199: RuntimeWarning: invalid value encountered in multiply
#   return np.multiply(self._var, x, out=out)
# /home/wollex/.local/share/virtualenvs/Programme-856uYgoc/lib/python3.8/site-packages/pymc3/step_methods/hmc/quadpotential.py:220: RuntimeWarning: divide by zero encountered in true_divide
#   np.divide(1, self._stds, out=self._inv_stds)
# /home/wollex/.local/share/virtualenvs/Programme-856uYgoc/lib/python3.8/site-packages/pymc3/step_methods/hmc/quadpotential.py:199: RuntimeWarning: invalid value encountered in multiply
#   return np.multiply(self._var, x, out=out)
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/wollex/.local/share/virtualenvs/Programme-856uYgoc/lib/python3.8/site-packages/pymc3/parallel_sampling.py", line 137, in run
#     self._start_loop()
#   File "/home/wollex/.local/share/virtualenvs/Programme-856uYgoc/lib/python3.8/site-packages/pymc3/parallel_sampling.py", line 191, in _start_loop
#     point, stats = self._compute_point()
#   File "/home/wollex/.local/share/virtualenvs/Programme-856uYgoc/lib/python3.8/site-packages/pymc3/parallel_sampling.py", line 216, in _compute_point
#     point, stats = self._step_method.step(self._point)
#   File "/home/wollex/.local/share/virtualenvs/Programme-856uYgoc/lib/python3.8/site-packages/pymc3/step_methods/arraystep.py", line 276, in step
#     apoint, stats = self.astep(array)
#   File "/home/wollex/.local/share/virtualenvs/Programme-856uYgoc/lib/python3.8/site-packages/pymc3/step_methods/hmc/base_hmc.py", line 147, in astep
#     self.potential.raise_ok(self._logp_dlogp_func._ordering.vmap)
#   File "/home/wollex/.local/share/virtualenvs/Programme-856uYgoc/lib/python3.8/site-packages/pymc3/step_methods/hmc/quadpotential.py", line 268, in raise_ok
#     raise ValueError("\n".join(errmsg))
# ValueError: Mass matrix contains zeros on the diagonal.
# The derivative of RV `tau_I_log__`.ravel()[0] is zero.
# The derivative of RV `tau_I_log__`.ravel()[1] is zero.
# The derivative of RV `tau_I_log__`.ravel()[2] is zero.
# The derivative of RV `tau_I_log__`.ravel()[3] is zero.
# The derivative of RV `sigma_tau_I_log__`.ravel()[0] is zero.
# The derivative of RV `mu_tau_I_log__`.ravel()[0] is zero.
# The derivative of RV `nu_bar`.ravel()[0] is zero.
# The derivative of RV `nu_bar`.ravel()[1] is zero.
# The derivative of RV `nu_bar`.ravel()[2] is zero.
# The derivative of RV `nu_bar`.ravel()[3] is zero.
# The derivative of RV `alpha_0_log__`.ravel()[0] is zero.
# The derivative of RV `alpha_0_log__`.ravel()[1] is zero.
# The derivative of RV `alpha_0_log__`.ravel()[2] is zero.
# The derivative of RV `alpha_0_log__`.ravel()[3] is zero.
# The derivative of RV `sigma_alpha_0_log__`.ravel()[0] is zero.
# The derivative of RV `mu_alpha_0_log__`.ravel()[0] is zero.
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ValueError: Mass matrix contains zeros on the diagonal.
# The derivative of RV `tau_I_log__`.ravel()[0] is zero.
# The derivative of RV `tau_I_log__`.ravel()[1] is zero.
# The derivative of RV `tau_I_log__`.ravel()[2] is zero.
# The derivative of RV `tau_I_log__`.ravel()[3] is zero.
# The derivative of RV `sigma_tau_I_log__`.ravel()[0] is zero.
# The derivative of RV `mu_tau_I_log__`.ravel()[0] is zero.
# The derivative of RV `nu_bar`.ravel()[0] is zero.
# The derivative of RV `nu_bar`.ravel()[1] is zero.
# The derivative of RV `nu_bar`.ravel()[2] is zero.
# The derivative of RV `nu_bar`.ravel()[3] is zero.
# The derivative of RV `alpha_0_log__`.ravel()[0] is zero.
# The derivative of RV `alpha_0_log__`.ravel()[1] is zero.
# The derivative of RV `alpha_0_log__`.ravel()[2] is zero.
# The derivative of RV `alpha_0_log__`.ravel()[3] is zero.
# The derivative of RV `sigma_alpha_0_log__`.ravel()[0] is zero.
# The derivative of RV `mu_alpha_0_log__`.ravel()[0] is zero.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
#      50     #logP_sum = np.nansum(logP_)
#      51         #if np.isnan(logP_sum):
#      52         #    logP_sum = -1000
#    (...)
#      56
#      57     # return logp_
#      59 logP = pm.DensityDist('logP',likelihood,observed=NU)
# ---> 61 trace = pm.sample(return_inferencedata=True)
#
# File ~/.local/share/virtualenvs/Programme-856uYgoc/lib/python3.8/site-packages/deprecat/classic.py:215, in deprecat.<locals>.wrapper_function(wrapped_, instance_, args_, kwargs_)
#     213         else:
#     214             warnings.warn(message, category=category, stacklevel=_routine_stacklevel)
# --> 215 return wrapped_(*args_, **kwargs_)
#
# File ~/.local/share/virtualenvs/Programme-856uYgoc/lib/python3.8/site-packages/pymc3/sampling.py:575, in sample(draws, step, init, n_init, initvals, trace, chain_idx, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, callback, jitter_max_retries, start, return_inferencedata, idata_kwargs, mp_ctx, pickle_backend, **kwargs)
#     573 _print_step_hierarchy(step)
#     574 try:
# --> 575     trace = _mp_sample(**sample_args, **parallel_args)
#     576 except pickle.PickleError:
#     577     _log.warning("Could not pickle model, sampling singlethreaded.")
#
# File ~/.local/share/virtualenvs/Programme-856uYgoc/lib/python3.8/site-packages/pymc3/sampling.py:1496, in _mp_sample(draws, tune, step, chains, cores, chain, random_seed, start, progressbar, trace, model, callback, discard_tuned_samples, mp_ctx, pickle_backend, **kwargs)
#    1494 try:
#    1495     with sampler:
# -> 1496         for draw in sampler:
#    1497             trace = traces[draw.chain - chain]
#    1498             if trace.supports_sampler_stats and draw.stats is not None:
#
# File ~/.local/share/virtualenvs/Programme-856uYgoc/lib/python3.8/site-packages/pymc3/parallel_sampling.py:479, in ParallelSampler.__iter__(self)
#     476     self._progress.update(self._total_draws)
#     478 while self._active:
# --> 479     draw = ProcessAdapter.recv_draw(self._active)
#     480     proc, is_last, draw, tuning, stats, warns = draw
#     481     self._total_draws += 1
#
# File ~/.local/share/virtualenvs/Programme-856uYgoc/lib/python3.8/site-packages/pymc3/parallel_sampling.py:359, in ProcessAdapter.recv_draw(processes, timeout)
#     357     else:
#     358         error = RuntimeError("Chain %s failed." % proc.chain)
# --> 359     raise error from old_error
#     360 elif msg[0] == "writing_done":
#     361     proc._readable = True
#
# RuntimeError: Chain 1 failed.

# %%
np.exp(-4.9)

# %%
az.plot_posterior(trace)
plt.tight_layout()

# %%
nu = np.linspace(0.,2.,101)
plt.plot(nu,approx_q({'tau_I': 0.005, 'alpha_0': 0.04, 'nu_bar': nu}))
plt.plot(nu,nu**2,'r--')
plt.show()

# %%
nu = np.linspace(0.1,10.,100)
p, log = logp_raw(nu,2.,0.02,0.005)
plt.plot(nu,p)
