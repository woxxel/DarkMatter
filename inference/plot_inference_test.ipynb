# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
root_dir = Path.cwd().parent
if not root_dir in sys.path: sys.path.insert(0,str(root_dir))


from inference.hpc_test_inference import *
# Out:
# /home/wollex/anaconda3/envs/inference/lib/python3.9/site-packages/paramiko/transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
ref_vals = {
    "gamma_1": 1.7,
    "delta_1": 4.5,
    "nu_max_1": 25.0,
    "T": 1200,
    "N": 1000,
}

# %%
plot_results(
    "gamma_1",
    np.linspace(1.1, 2.0, 10),
    n_repeat=100,
    ref_values=ref_vals.copy(),
    base_path=str(Path(root_dir, "results_inference/24_11_13/inference_test")),
    save=False,
    log=False,
)
# Out:
# {'gamma_1': 1.7, 'delta_1': 4.5, 'nu_max_1': 25.0, 'T': 1200, 'N': 1000}

# %%
plot_results(
    "delta_1",
    np.linspace(3.0, 8.0, 11),
    n_repeat=100,
    ref_values=ref_vals.copy(),
    base_path=str(Path(root_dir, "results_inference/24_11_13/inference_test")),
    save=False,
    log=False,
)
# Out:
# {'gamma_1': 1.7, 'delta_1': 4.5, 'nu_max_1': 25.0, 'T': 1200, 'N': 1000}
# /home/wollex/Documents/Science/WolfGroup/DarkMatter/Programme/inference/utils/utils.py:21: RuntimeWarning: divide by zero encountered in divide
#   p[NU_mask] = gamma / ( nu_max * np.sqrt( -np.pi * np.log( NU_scaled ) ) ) * \

# %%
plot_results(
    "nu_max_1",
    np.linspace(15.0, 65.0, 6),
    n_repeat=100,
    ref_values=ref_vals.copy(),
    base_path=str(Path(root_dir, "results_inference/24_11_13/inference_test")),
    save=False,
    log=False,
)
# Out:
# {'gamma_1': 1.7, 'delta_1': 4.5, 'nu_max_1': 25.0, 'T': 1200, 'N': 1000}
# /home/wollex/Documents/Science/WolfGroup/DarkMatter/Programme/inference/utils/utils.py:21: RuntimeWarning: divide by zero encountered in divide
#   p[NU_mask] = gamma / ( nu_max * np.sqrt( -np.pi * np.log( NU_scaled ) ) ) * \

# %%
plot_results(
    "N",
    [10, 20, 50, 100, 200, 500, 1000],
    n_repeat=100,
    ref_values=ref_vals.copy(),
    base_path=str(Path(root_dir, "results_inference/24_11_13/inference_test")),
    save=False,
    log=True,
)
# Out:
# {'gamma_1': 1.7, 'delta_1': 4.5, 'nu_max_1': 25.0, 'T': 1200, 'N': 1000}
# /home/wollex/Documents/Science/WolfGroup/DarkMatter/Programme/inference/utils/utils.py:21: RuntimeWarning: divide by zero encountered in divide
#   p[NU_mask] = gamma / ( nu_max * np.sqrt( -np.pi * np.log( NU_scaled ) ) ) * \

# %%
plot_results(
    "T",
    [1, 2, 5, 10, 30, 60, 120],
    n_repeat=100,
    ref_values=ref_vals.copy(),
    base_path=str(Path(root_dir, "results_inference/24_11_13/inference_test")),
    save=False,
    log=True,
)
# Out:
# {'gamma_1': 1.7, 'delta_1': 4.5, 'nu_max_1': 25.0, 'T': 1200, 'N': 1000}

# %%
ref_vals = {
    "gamma_1": 1.2,
    "delta_1": 4.5,
    "nu_max_1": 25.0,
    "p": 0.35,
    "gamma_2": 3.0,
    "delta_2": 7.0,
    "nu_max_2": 25.0,
    "T": 1200,
    "N": 1000,
}

# %%
plot_results(
    "gamma_1",
    np.linspace(1.1, 2.0, 10),
    n_repeat=100,
    ref_values=ref_vals.copy(),
    base_path=str(Path(root_dir, "results_inference/24_11_13/inference_test")),
    save=False,
    log=False,
)
# Out:
# {'gamma_1': 1.2, 'delta_1': 4.5, 'nu_max_1': 25.0, 'p': 0.35, 'gamma_2': 3.0, 'delta_2': 7.0, 'nu_max_2': 25.0, 'T': 1200, 'N': 1000}

# %%
plot_results(
    "gamma_2",
    np.linspace(2.0, 3.0, 6),
    n_repeat=100,
    ref_values=ref_vals.copy(),
    base_path=str(Path(root_dir, "results_inference/24_11_13/inference_test")),
    save=False,
    log=False,
)
# Out:
# {'gamma_1': 1.2, 'delta_1': 4.5, 'nu_max_1': 25.0, 'p': 0.35, 'gamma_2': 3.0, 'delta_2': 7.0, 'nu_max_2': 25.0, 'T': 1200, 'N': 1000}
